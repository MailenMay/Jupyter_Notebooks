# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,5,11)
y = np.sin(x) #Aplico la funcion seno a X

# %%
fig, axes = plt.subplots()
axes.plot(x,y,'b')

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)
axes[0].plot(x,y,'b')
axes[1].plot(y,x,'r')

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)
ax1.plot(x,y,'b')
ax2.plot(y,x,'r')

# %%
fig, axes = plt.subplots(2,4)
axes[0,0].plot(x,np.cos(x))
axes[0,1].plot(x,np.sin(x),'y')
axes[0,2].plot(x,np.tan(x),'r')
axes[0,3].plot(x,np.cos(x)** 2)

# %%
fig, ((ax1, ax2, ax3, ax4), (ax5,ax6,ax7,ax8)) = plt.subplots(2,4)
ax1.plot(x,np.cos(x))
ax2.plot(x,np.sin(x),'y')
ax3.plot(x,np.tan(x),'r')
ax4.plot(x,np.cos(x)** 2)
fig.tight_layout()

# %% [markdown]
# # Reto

# %%
fig, ((ax1, ax2, ax3, ax4), (ax5,ax6,ax7,ax8)) = plt.subplots(2,4)
ax1.plot(-x,'r',x,'r')
ax2.plot(x,x**2,'go--',-(x**2),'go--',mae)
ax3.plot(x**3,'bo',-(x**3),'bo')
ax4.plot(x,np.sqrt(x),'r+',-(np.sqrt(x)),'r+')
ax5.plot(x,np.abs(x),linewidth=2,markersize=12)
ax6.plot(1/x,'g',-(1/x),'g',linestyle = 'dashed' ,linewidth=2,markersize=12)
ax7.plot(x,np.sin(x),np.arcsin(x),color='k')
ax8.plot(x,np.cos(x),'salmon',np.arccos(x),'salmon')
fig.tight_layout()
# Out:
# /tmp/ipykernel_2568/2154413514.py:7: RuntimeWarning: divide by zero encountered in true_divide
#   ax6.plot(1/x,'g',-(1/x),'g',linestyle = 'dashed' ,linewidth=2,markersize=12)
# /tmp/ipykernel_2568/2154413514.py:8: RuntimeWarning: invalid value encountered in arcsin
#   ax7.plot(x,np.sin(x),np.arcsin(x),color='k')
# /tmp/ipykernel_2568/2154413514.py:9: RuntimeWarning: invalid value encountered in arccos
#   ax8.plot(x,np.cos(x),'salmon',np.arccos(x),'salmon')
